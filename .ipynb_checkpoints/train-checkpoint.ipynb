# %%
import  os 
imgs  = os.listdir('data')
import  random 
print(imgs)
# Out:
# ['test', 'train']

# %%
# train = imgs[0:int(0.8*len(imgs))]
# test  = imgs[int(0.8*len(imgs)):]

# %%
import  matplotlib.pyplot  as  plt 
import  cv2
import numpy as np 
import  random
from tensorflow.python.keras.optimizers import Adam
from tensorflow.python.keras.applications.vgg16 import VGG16
from tensorflow.python.keras.layers import  Input
from tensorflow.python.keras.layers  import  Flatten
from tensorflow.python.keras import layers
import tensorflow  as tf
from tensorflow.python.keras import  Model
# Out:
# C:\Users\82108\.conda\envs\tf\lib\site-packages\tensorflow\python\framework\dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\82108\.conda\envs\tf\lib\site-packages\tensorflow\python\framework\dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\82108\.conda\envs\tf\lib\site-packages\tensorflow\python\framework\dtypes.py:521: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\82108\.conda\envs\tf\lib\site-packages\tensorflow\python\framework\dtypes.py:522: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\82108\.conda\envs\tf\lib\site-packages\tensorflow\python\framework\dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\82108\.conda\envs\tf\lib\site-packages\tensorflow\python\framework\dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
IMG_SHAPE = (224, 224)

# %%
import  os  
imgs = os.listdir('data\\train')

# %%
# imgs
'data\\train\\'+imgs[0]
# Out:
# 'data\\train\\000002.jpg'

# %%
img  = cv2.imread('data\\train\\'+imgs[0])
img  = cv2.resize(img, IMG_SHAPE)

# %%
def rotate_image(image, angle):
    image_center = tuple(np.array(image.shape[1::-1]) / 2)
    rot_mat = cv2.getRotationMatrix2D(image_center, angle, 1.0)
    result = cv2.warpAffine(image, rot_mat, image.shape[1::-1], flags=cv2.INTER_LINEAR)
    return result

# %%
plt.imshow(img)
plt.show()

# %%
im_rot  = rotate_image(img, 90)

# %%
plt.imshow(im_rot)
plt.show()

# %%
from scipy import ndimage

#rotation angle in degree
im_rot2 = ndimage.rotate(img, 45)

# %%
plt.imshow(im_rot2)
plt.show()

# %%
from tensorflow.python.keras.applications.vgg16 import VGG16

# %%
# def  base_model(input_layer):
#     model = VGG16(weights='imagenet',input_shape=IMG_SHAPE ,include_top=False )(input_layer)
#     model.trainable=False
#     global_average_layer = tf.keras.layers.GlobalAveragePooling2D()
#     feature_batch_average = global_average_layer(model)
#     prediction_layer = tf.keras.layers.Dense(10)(feature_batch_average)
#     return prediction_layer

# %%
IMG_SHAPE[:2]+(3,)
# Out:
# (224, 224, 3)

# %%
model = VGG16(weights='imagenet',input_shape=IMG_SHAPE[:2]+(3,), include_top=False )
model.trainable=True

# %%
ref_image = Input(shape = (IMG_SHAPE+(3,)), name='ref_input')
rot_image = Input(shape = (IMG_SHAPE+(3,)), name='rot_input')

ref   = model(ref_image)
rot   = model(rot_image)

ref   = tf.keras.layers.GlobalAveragePooling2D()(ref)
rot   = tf.keras.layers.GlobalAveragePooling2D()(rot)
                                                 
# ref   = Flatten()(ref )
# rot   = Flatten()(rot )

conc = tf.keras.layers.Concatenate()([ref , rot])
conc = layers.Dropout(0.5)(conc)
conc = layers.Dense(128, activation='relu',)(conc)
predict = layers.Dense(1, )(conc)

# %%
m = Model(inputs=[ref_image, rot_image],
                      outputs=predict)

# %%
m.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# ref_input (InputLayer)          (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# rot_input (InputLayer)          (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# vgg16 (Model)                   (None, 7, 7, 512)    14714688    ref_input[0][0]
#                                                                  rot_input[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_1 (Glo (None, 512)          0           vgg16[1][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_2 (Glo (None, 512)          0           vgg16[2][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 1024)         0           global_average_pooling2d_1[0][0]
#                                                                  global_average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 1024)         0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 128)          131200      dropout_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 1)            129         dense_1[0][0]
# ==================================================================================================
# Total params: 14,846,017
# Trainable params: 14,846,017
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
class Batch(tf.keras.utils.Sequence):
    def __init__(self, files,  batchsize,IMG_SHAPE = IMG_SHAPE, base_path = 'data\\train', shuffle = True ):
        self.IMG_SHAPE = IMG_SHAPE
        data = []
        self.files = os.listdir(base_path)
        for i in range(100):
            for j in files:
                data.append((j, random.random()))
        self.data   = data
        self.length = len(data) 
        self.batchsize = batchsize
        self.index     = 0 
        self.base_path = base_path
        
    def __len__(self):
        return len(self.data)//self.batchsize
    
    def ougment(self, image):
        image  = (image  - np.array([123.68, 116.779, 103.939]))/255.0
        return image
        

    def __getitem__(self, index):
        batch_data  = self.data[index*self.batchsize:(index+1)*self.batchsize]
        x1 = []
        x2 = []
        y  = []
        
        for dt  in batch_data: 
            
            img  = cv2.imread(self.base_path+'/'+dt[0] )
            img  = cv2.resize(img, self.IMG_SHAPE)
            rotate  = dt[1]
            rot = rotate_image(img , rotate*360)
            self.index+=1
            x1.append(self.ougment(img))
            x2.append(self.ougment(rot))
            y.append(dt[1])
            
        return [np.array(x1), np.array(x2)], y
        
        
    def on_epoch_end(self):
        
        data = []
        self.files = os.listdir(self.base_path)
        for i in range(100):
            for j in self.files:
                data.append((j, random.random()))
        self.data   = data
        print('epoch  has  ended ')

# %%
train_batches = Batch([], 32,base_path='data\\train')
test_batches = Batch([], 32,base_path='data\\test')

# %%
# train_batches.on_epoch_end()
# train_batches.data
# Out:
# epoch  has  ended
# [('000002.jpg', 0.5125945594542465),
#  ('000008.jpg', 0.5873182177291849),
#  ('000020.jpg', 0.42851810826967296),
#  ('000031.jpg', 0.9676914801055345),
#  ('000035.jpg', 0.4917295384057462),
#  ('000058.jpg', 0.3638060633984055),
#  ('000083.jpg', 0.484949712747894),
#  ('000089.jpg', 0.3132172927903041),
#  ('000145.jpg', 0.16643562625751118),
#  ('000164.jpg', 0.30284221270744827),
#  ('000191.jpg', 0.39226723354455495),
#  ('000192.jpg', 0.177219576970173),
#  ('000400.jpg', 0.9531970483535014),
#  ('000436.jpg', 0.5409882357681189),
#  ('000452.jpg', 0.7809506438607521),
#  ('000496.jpg', 0.11571250807725375),
#  ('000510.jpg', 0.25704184893985593),
#  ('000557.jpg', 0.9775809054172745),
#  ('000575.jpg', 0.1430148111107422),
#  ('000591.jpg', 0.10463172416632638),
#  ('000594.jpg', 0.0062148397659606),
#  ('000600.jpg', 0.16052935930793355),
#  ('000641.jpg', 0.37690007875289067),
#  ('000643.jpg', 0.6736821787034377),
#  ('000648.jpg', 0.3492528552667016),
#  ('000665.jpg', 0.24193870305090548),
#  ('000696.jpg', 0.7231732006500388),
#  ('000772.jpg', 0.8746445489184446),
#  ('000773.jpg', 0.3132768891709592),
#  ('000781.jpg', 0.232727112985478),
#  ('000793.jpg', 0.16407126313391496),
#  ('000807.jpg', 0.6289748984869686),
#  ('000868.jpg', 0.41978435509100465),
#  ('000880.jpg', 0.8159306175933049),
#  ('000889.jpg', 0.06643362633769045),
#  ('000890.jpg', 0.6192073078544336),
#  ('000939.jpg', 0.17053602930354383),
#  ('000957.jpg', 0.7368239553445897),
#  ('000998.jpg', 0.5350400516205032),
#  ('000008.jpg', 0.7730743471016371),
#  ('000020.jpg', 0.034564320608857835),
#  ('000031.jpg', 0.09729031686037393),
#  ('000035.jpg', 0.8847756944981234),
#  ('000058.jpg', 0.846665201008833),
#  ('000083.jpg', 0.08253909119688085),
#  ('000089.jpg', 0.336665329387839),
#  ('000145.jpg', 0.7882244279562358),
#  ('000164.jpg', 0.07473775593939902),
#  ('000191.jpg', 0.395789613652334),
#  ('000192.jpg', 0.6650066069601215),
#  ('000400.jpg', 0.8132883947873948),
#  ('000436.jpg', 0.4663912506417637),
#  ('000452.jpg', 0.4942685272287508),
#  ('000496.jpg', 0.8650114538979358),
#  ('000510.jpg', 0.12464455066387381),
#  ('000557.jpg', 0.1893720166968258),
#  ('000575.jpg', 0.7192458699867218),
#  ('000591.jpg', 0.507495699606031),
#  ('000594.jpg', 0.10245980549586542),
#  ('000600.jpg', 0.5295567708149862),
#  ('000641.jpg', 0.5710276838291718),
#  ('000643.jpg', 0.08434316168219147),
#  ('000648.jpg', 0.09673447396358459),
#  ('000665.jpg', 0.46476511156515443),
#  ('000696.jpg', 0.8116435799183714),
#  ('000772.jpg', 0.8847114165639584),
#  ('000773.jpg', 0.5476282466749439),
#  ('000781.jpg', 0.7253467617277748),
#  ('000793.jpg', 0.10311950936685033),
#  ('000807.jpg', 0.03499034063811157),
#  ('000868.jpg', 0.8624737306892902),
#  ('000880.jpg', 0.16946951231371254),
#  ('000889.jpg', 0.7747000937691572),
#  ('000890.jpg', 0.827403178387298),
#  ('000939.jpg', 0.9270322045173583),
#  ('000957.jpg', 0.1636951316088714),
#  ('000998.jpg', 0.2871438053864447),
#  ('001047.jpg', 0.9302698202119732),
#  ('001057.jpg', 0.08416790493110538),
#  ...]

# %%
opt = Adam(lr=1e-4)
m.compile(loss="MSE", optimizer=opt,metrics=["MAE"])

# %%
mchk=tf.keras.callbacks.ModelCheckpoint( filepath='model\\model.h5',  monitor="val_loss", verbose=1,
    save_best_only=True, save_weights_only=True, mode="auto")

# %%
m.fit_generator(
    train_batches, steps_per_epoch=train_batches.length//train_batches.batchsize, epochs=100, verbose=1,  
    validation_data=test_batches, validation_steps=test_batches.length//test_batches.batchsize, 
    class_weight=None, max_queue_size=10,   use_multiprocessing=False,
    callbacks=[mchk,],
)
# Out:
# Epoch 1/100
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\82108\.conda\envs\tf\lib\logging\__init__.py", line 994, in emit
#     msg = self.format(record)
#   File "C:\Users\82108\.conda\envs\tf\lib\logging\__init__.py", line 840, in format
#     return fmt.format(record)
#   File "C:\Users\82108\.conda\envs\tf\lib\logging\__init__.py", line 577, in format
#     record.message = record.getMessage()
#   File "C:\Users\82108\.conda\envs\tf\lib\logging\__init__.py", line 338, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "C:\Users\82108\.conda\envs\tf\lib\runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "C:\Users\82108\.conda\envs\tf\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\82108\.conda\envs\tf\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "C:\Users\82108\.conda\envs\tf\lib\site-packages\traitlets\config\application.py", line 664, in launch_instance
#     app.start()
#   File "C:\Users\82108\.conda\envs\tf\lib\site-packages\ipykernel\kernelapp.py", line 619, in start
#     self.io_loop.start()
#   File "C:\Users\82108\.conda\envs\tf\lib\site-packages\tornado\platform\asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\82108\.conda\envs\tf\lib\asyncio\base_events.py", line 442, in run_forever
#     self._run_once()
#   File "C:\Users\82108\.conda\envs\tf\lib\asyncio\base_events.py", line 1462, in _run_once
#     handle._run()
#   File "C:\Users\82108\.conda\envs\tf\lib\asyncio\events.py", line 145, in _run
#     self._callback(*self._args)
#   File "C:\Users\82108\.conda\envs\tf\lib\site-packages\tornado\ioloop.py", line 688, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "C:\Users\82108\.conda\envs\tf\lib\site-packages\tornado\ioloop.py", line 741, in _run_callback
#     ret = callback()
#   File "C:\Users\82108\.conda\envs\tf\lib\site-packages\tornado\gen.py", line 814, in inner
#     self.ctx_run(self.run)
#   File "C:\Users\82108\.conda\envs\tf\lib\site-packages\contextvars\__init__.py", line 38, in run
#     return callable(*args, **kwargs)
#   File "C:\Users\82108\.conda\envs\tf\lib\site-packages\tornado\gen.py", line 775, in run
#     yielded = self.gen.send(value)
#   File "C:\Users\82108\.conda\envs\tf\lib\site-packages\ipykernel\kernelbase.py", line 374, in dispatch_queue
#     yield self.process_one()
#   File "C:\Users\82108\.conda\envs\tf\lib\site-packages\tornado\gen.py", line 250, in wrapper
#     runner = Runner(ctx_run, result, future, yielded)
#   File "C:\Users\82108\.conda\envs\tf\lib\site-packages\tornado\gen.py", line 741, in __init__
#     self.ctx_run(self.run)
#   File "C:\Users\82108\.conda\envs\tf\lib\site-packages\contextvars\__init__.py", line 38, in run
#     return callable(*args, **kwargs)
#   File "C:\Users\82108\.conda\envs\tf\lib\site-packages\tornado\gen.py", line 775, in run
#     yielded = self.gen.send(value)
#   File "C:\Users\82108\.conda\envs\tf\lib\site-packages\ipykernel\kernelbase.py", line 358, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "C:\Users\82108\.conda\envs\tf\lib\site-packages\tornado\gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "C:\Users\82108\.conda\envs\tf\lib\site-packages\contextvars\__init__.py", line 38, in run
#     return callable(*args, **kwargs)
#   File "C:\Users\82108\.conda\envs\tf\lib\site-packages\ipykernel\kernelbase.py", line 261, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "C:\Users\82108\.conda\envs\tf\lib\site-packages\tornado\gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "C:\Users\82108\.conda\envs\tf\lib\site-packages\contextvars\__init__.py", line 38, in run
#     return callable(*args, **kwargs)
#   File "C:\Users\82108\.conda\envs\tf\lib\site-packages\ipykernel\kernelbase.py", line 538, in execute_request
#     user_expressions, allow_stdin,
#   File "C:\Users\82108\.conda\envs\tf\lib\site-packages\tornado\gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "C:\Users\82108\.conda\envs\tf\lib\site-packages\contextvars\__init__.py", line 38, in run
#     return callable(*args, **kwargs)
#   File "C:\Users\82108\.conda\envs\tf\lib\site-packages\ipykernel\ipkernel.py", line 302, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "C:\Users\82108\.conda\envs\tf\lib\site-packages\ipykernel\zmqshell.py", line 539, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "C:\Users\82108\.conda\envs\tf\lib\site-packages\IPython\core\interactiveshell.py", line 2714, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "C:\Users\82108\.conda\envs\tf\lib\site-packages\IPython\core\interactiveshell.py", line 2824, in run_ast_nodes
#     if self.run_code(code, result):
#   File "C:\Users\82108\.conda\envs\tf\lib\site-packages\IPython\core\interactiveshell.py", line 2878, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-25-84478da1ff76>", line 5, in <module>
#     callbacks=[mchk,],
#   File "C:\Users\82108\.conda\envs\tf\lib\site-packages\tensorflow\python\keras\_impl\keras\engine\training.py", line 1598, in fit_generator
#     initial_epoch=initial_epoch)
#   File "C:\Users\82108\.conda\envs\tf\lib\site-packages\tensorflow\python\keras\_impl\keras\engine\training_generator.py", line 231, in fit_generator
#     callbacks.on_epoch_end(epoch, epoch_logs)
#   File "C:\Users\82108\.conda\envs\tf\lib\site-packages\tensorflow\python\keras\_impl\keras\callbacks.py", line 95, in on_epoch_end
#     callback.on_epoch_end(epoch, logs)
#   File "C:\Users\82108\.conda\envs\tf\lib\site-packages\tensorflow\python\keras\_impl\keras\callbacks.py", line 457, in on_epoch_end
#     'skipping.', self.monitor, RuntimeWarning)
#   File "C:\Users\82108\.conda\envs\tf\lib\site-packages\tensorflow\python\platform\tf_logging.py", line 126, in warning
#     _get_logger().warning(msg, *args, **kwargs)
# Message: 'Can save best model only with %s available, skipping.'
# Arguments: ('val_loss', <class 'RuntimeWarning'>)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-25-84478da1ff76> in <module>()
#       3     validation_data=test_batches, validation_steps=test_batches.length//test_batches.batchsize,
#       4     class_weight=None, max_queue_size=10,   use_multiprocessing=False,
# ----> 5     callbacks=[mchk,],
#       6 )
#
# C:\Users\82108\.conda\envs\tf\lib\site-packages\tensorflow\python\keras\_impl\keras\engine\training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1596         use_multiprocessing=use_multiprocessing,
#    1597         shuffle=shuffle,
# -> 1598         initial_epoch=initial_epoch)
#    1599
#    1600   def evaluate_generator(self,
#
# C:\Users\82108\.conda\envs\tf\lib\site-packages\tensorflow\python\keras\_impl\keras\engine\training_generator.py in fit_generator(model, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#     229           break
#     230
# --> 231       callbacks.on_epoch_end(epoch, epoch_logs)
#     232       epoch += 1
#     233       if callback_model.stop_training:
#
# C:\Users\82108\.conda\envs\tf\lib\site-packages\tensorflow\python\keras\_impl\keras\callbacks.py in on_epoch_end(self, epoch, logs)
#      93     logs = logs or {}
#      94     for callback in self.callbacks:
# ---> 95       callback.on_epoch_end(epoch, logs)
#      96
#      97   def on_batch_begin(self, batch, logs=None):
#
# C:\Users\82108\.conda\envs\tf\lib\site-packages\tensorflow\python\keras\_impl\keras\callbacks.py in on_epoch_end(self, epoch, logs)
#     353         self.log_values.append((k, logs[k]))
#     354     if self.verbose:
# --> 355       self.progbar.update(self.seen, self.log_values)
#     356
#     357
#
# AttributeError: 'ProgbarLogger' object has no attribute 'log_values'

# %%
#  os.listdir('data')

# %%
imtest=cv2.imread('data\\000008.jpg')

imtest = (imtest  - np.array([123.68, 116.779, 103.939]))/255.0
imtest  = cv2.resize(imtest, IMG_SHAPE)
imtest.shape

# %%
imtest2 = rotate_image(imtest,270)

# %%
m.predict([np.array([imtest,]), np.array([imtest2,])])
